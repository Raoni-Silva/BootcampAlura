# %% [markdown]
# <a href="https://colab.research.google.com/github/Raoni-Silva/BootcampAlura/blob/main/Bootcamp_DataScience_Alura_Mod01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá,
# me chamo Raoni, tenho 34 anos, sou engenheiro mecânico e aspirante a cientista de dados.
# Este é meu notebook do módulo 01 das aulas do Bootcamp Data Science Aplicada da Alura.

# %%
#@title Importação das bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # AULA 01 - Python e Pandas para análise de dados reais

# %%
#@title Carregando a base de dados e explorando a base de dados
fonte = 'https://raw.githubusercontent.com/Raoni-Silva/BootcampAlura/main/A092655189_28_143_208_atendimento.csv'
dados = pd.read_csv(fonte, encoding='ISO-8859-1',
                    skiprows = 3, sep=';', skipfooter=12,
                    thousands='.', decimal=',', engine='python')
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados['2008/Ago']
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
#@title Plotagem dos dados em gráficos
dados.plot(x='Unidade da Federação', y='2008/Ago')

# %%
#Gráfico de barra
dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))

# %%
#Melhorando a visualização do eixo y
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Valor por unidade da Federação')
plt.show()

# %% [markdown]
# ## DESAFIO 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('SUS | Gastos em procedimentos hospitalares\npor unidade da Federação - Agosto de 2008', {'size':20}).set_color('b')
plt.show()

# %% [markdown]
# ## DESAFIO 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
ax = dados.plot(x='Unidade da Federação', y='2020/Jul', kind='bar', figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('SUS | Gastos em procedimentos hospitalares\npor unidade da Federação - Julho de 2020', {'size':20}).set_color('b')
plt.ylabel('Valores em reais', {'size':15})
plt.xlabel('Unidade da Federação', {'size':15})
plt.show()

# %% [markdown]
# # AULA 02 - Primeiras visualizações de dados

# %%
#@title Explorando os dados
dados[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
#Criar uma lista com apenas os meses que contenham dados.
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
#Criando um DF apenas com os meses que contenham dados
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
#Setando como index a coluna "Unidade da Federação"
usaveis = usaveis.set_index('Unidade da Federação')
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  929129659.72
# 12 Acre               10470.07  14001.71  ...  1163813.08  420668039.63
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1771654871.23
# 14 Roraima             4785.91  11858.63  ...  2739498.41  305010883.18
# 15 Pará              181159.29 433414.74  ... 27618727.51 4437115730.71
#
# [5 rows x 157 columns]

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
#Explorando graficamente os dados
usaveis.plot(figsize=(12,6))

# %%
#Invertendo o DF
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
#Plotando o DF invertido
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# Foi identificado que há um dado estranho no final do gráfico e portanto precisa ser checado.

# %%
usaveis.tail()
# Out:
#                         2007/Ago   2007/Set  ...    2020/Jul          Total
# Unidade da Federação                         ...
# 43 Rio Grande do Sul  1049252.33 3182913.14  ... 78929703.81 11958647088.33
# 50 Mato Grosso do Sul  199556.12  573675.41  ... 12508717.35  2172157981.36
# 51 Mato Grosso          63562.50  232444.62  ... 13083151.70  2036923784.59
# 52 Goiás               179395.82  418053.58  ... 33499284.38  4657348958.66
# 53 Distrito Federal    191951.47  769966.25  ... 22233542.26  2429933198.76
#
# [5 rows x 157 columns]

# %% [markdown]
# O problema está na última coluna Total que precisa ser ignorada na plotagem

# %%
usaveis.T[:-1].tail()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# 2020/Jul               7407388.24 1163813.08  ... 33499284.38          22233542.26
#
# [5 rows x 27 columns]

# %%
#plotagem sem a coluna total
usaveis.T[:-1].plot(figsize=(10,6))

# %% [markdown]
# ## DESAFIO 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
usaveis.T[:-1].plot(figsize=(10,6))
plt.legend(loc=(1.1,-0.2), borderaxespad=0).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# ## DESAFIO 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência
#
# Serão utilizados os 5 estados com maior gasto em procedimentos hospitalares

# %%
#Ordenando o DF por total
ordenado_por_total = usaveis.sort_values('Total', ascending=False)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 38929353900.57
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34 19160106499.88
# 41 Paraná             554800.22 1431708.01  ...  80320852.69 13786964617.27
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81 11958647088.33
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  9696362872.68
#
# [5 rows x 157 columns]

# %%
#Criando a lista dos top 5
top_5_index = list(ordenado_por_total.index[:5])
top_5_index
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro']

# %%
ax = (ordenado_por_total.T[top_5_index][:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 5 estados com maior\nparticipação de agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.show()

# %% [markdown]
# # AULA 03 - Manipulação de dados

# %%
ax = usaveis.T[:-1].plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.legend(loc=(1.1,-0.2)).set_title('Unidades da Federação')
plt.title('Gastos em procedimentos hospitalares por unidade\nda Federação de agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.show()

# %%
#@title Limpando os dados desnecessários
colunas_interessadas = usaveis[usaveis.columns[6:-1]]
colunas_interessadas.head()
# Out:
#                         2008/Fev    2008/Mar  ...    2020/Jun    2020/Jul
# Unidade da Federação                          ...
# 11 Rondônia           1940792.63  1955721.68  ...  9193593.76  7407388.24
# 12 Acre               1743978.66  2057439.02  ...  2199920.70  1163813.08
# 13 Amazonas           7934652.10  8641517.13  ... 17509334.66 13358514.02
# 14 Roraima             771687.83   876091.18  ...  3216466.51  2739498.41
# 15 Pará              20126081.01 22149375.82  ... 35396030.78 27618727.51
#
# [5 rows x 150 columns]

# %% [markdown]
# ## Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.

# %%
ax = (colunas_interessadas.T / 1000000).plot(figsize=(10,6), colormap='brg')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(loc=(1.1,-0.2)).set_title('Unidades da Federação')
plt.title('Gastos em procedimentos hospitalares por unidade\nda Federação de agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})

plt.show()

# %% [markdown]
# ## Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
#Criando um dicionário
mapa = {'1': 'Norte', '2': 'Nordeste', '3': 'Sudeste', '4': 'Sul', '5': 'Centro Oeste'}

#Obtendo o primeiro caracter de cada UF
UF = colunas_interessadas.index
num_regiao = UF.str.slice(start=0, stop=1)

#Criando a coluna com as regiões
coluna_regiao = num_regiao.map(mapa)

#Adicionando a coluna Região ao df
#colunas_interessadas.insert(0, 'Região', '')
colunas_interessadas['Região'] = coluna_regiao

colunas_interessadas.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                         2008/Fev    2008/Mar  ...    2020/Jul  Região
# Unidade da Federação                          ...
# 11 Rondônia           1940792.63  1955721.68  ...  7407388.24   Norte
# 12 Acre               1743978.66  2057439.02  ...  1163813.08   Norte
# 13 Amazonas           7934652.10  8641517.13  ... 13358514.02   Norte
# 14 Roraima             771687.83   876091.18  ...  2739498.41   Norte
# 15 Pará              20126081.01 22149375.82  ... 27618727.51   Norte
#
# [5 rows x 151 columns]

# %% [markdown]
# ## Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável.

# %%
ax = (colunas_interessadas.T[top_5_index][:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 5 estados com maior\nparticipação de agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# ## Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente. Caso seu estado já esteja adicionado coloque outro estado de sua escolha

# %%
ax = (colunas_interessadas.T[top_5_index][:-1] / 1000000).plot(figsize=(15,10))
ax2 = (colunas_interessadas.T['53 Distrito Federal'][:-1] / 1000000).plot()
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 5 estados com maior\nparticipação de agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# ## Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue.
#
# Utilizei uma base de dados dos casos no Brasil de 2008 a 2014

# %%
#Carregando a base de dados dos casos de dengue no Brasil
fonte_dengue = 'https://raw.githubusercontent.com/Raoni-Silva/BootcampAlura/main/Dengue_Brazil.csv'
dados_dengue = pd.read_csv(fonte_dengue, encoding='ISO-8859-1')
dados_dengue_2008_2014 = dados_dengue[18:]
dados_dengue_2008_2014 = dados_dengue_2008_2014.set_index('Year')
dados_dengue_2008_2014
# Out:
#         Cases  Deaths  Population
# Year
# 2008   734384     212   192979029
# 2009   528883     298   194895996
# 2010  1004392     673   196796269
# 2011   764032     482   198686688
# 2012   593093     284   200560983
# 2013  1468873     545   202408632
# 2014   591080     410   204213133

# %%
#Criando a lista com os anos de interesse
ano = colunas_interessadas.columns.str.slice(start=0, stop=4).unique()[:-1]
ano
# Out:
# Index(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
#Criando séries com as somas dos gastos por ano por estado
ano_2008 = colunas_interessadas.loc[: ,'2008/Fev':'2008/Dez'].sum(axis=1)
ano_2009 = colunas_interessadas.loc[: ,'2009/Jan':'2009/Dez'].sum(axis=1)
ano_2010 = colunas_interessadas.loc[: ,'2010/Jan':'2010/Dez'].sum(axis=1)
ano_2011 = colunas_interessadas.loc[: ,'2011/Jan':'2011/Dez'].sum(axis=1)
ano_2012 = colunas_interessadas.loc[: ,'2012/Jan':'2012/Dez'].sum(axis=1)
ano_2013 = colunas_interessadas.loc[: ,'2013/Jan':'2013/Dez'].sum(axis=1)
ano_2014 = colunas_interessadas.loc[: ,'2014/Jan':'2014/Dez'].sum(axis=1)

# %%
#Criação do DataFrame com os dados por ano
dados_2008_2014 = pd.DataFrame([ano_2008, ano_2009, ano_2010, ano_2011, ano_2012, ano_2013, ano_2014]).T
#Renomeando as colunas com os anos
dados_2008_2014.columns = ano[0:7]

x = dados_2008_2014.T.index
y1 = dados_2008_2014.mean()/1000000
y2 = dados_dengue_2008_2014['Cases']

#Criar a área de plotagem e os dois eixos y
fig, ax1 = plt.subplots(figsize=(10,6))
ax2 = ax1.twinx()

curva1, = ax1.plot(x, y1, label='Gasto por ano', color='r', marker=".", markersize=15)
curva2, = ax2.plot(x, y2, label='Casos de dengue', color='b',  marker=".", markersize=15)

#Criar uma lista para acessar os parametros das curvas
curvas = [curva1, curva2]

#Criar a legenda do gráfico
ax1.legend(curvas, [curve.get_label() for curve in curvas])

#Criar os labels de cada eixo
ax1.set_xlabel('Ano', {'size':15})
ax1.set_ylabel('Valores em milhões de reais', {'size':15}, color=curva1.get_color())
ax2.set_ylabel('Casos de dengue', {'size':15}, color=curva2.get_color())

#Alterar a cor dos eixos y
ax1.tick_params(axis='y', colors=curva1.get_color())
ax2.tick_params(axis='y', colors=curva2.get_color())

#Setar os valores dos eixos y
ax1.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
ax2.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.title('Comparativo anual de gastos\ncom saúde X Casos de dengue\n(Brasil)', {'size':15})
plt.show()

# %% [markdown]
# Comparando os dados do Brasil inteiro não parece haver uma clara relação entre aumento nos casos de dengue e aumento nos gastos com saúde. Seria mais eficiente fazer esse comparativo em algum estado específico, para entender melhor.

# %% [markdown]
# ## Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região.

# %%
ax = (colunas_interessadas.query('Região == "Sudeste"').loc[:,'2008/Fev':'2020/Jul']/1000000).T.plot(figsize=(10,6), colormap='brg')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.legend(loc=(1.1,0.5)).set_title('Unidades da Federação')
plt.title('Gastos em procedimentos hospitalares no Sudeste\nda Federação - Fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})

plt.show()

# %% [markdown]
# Os picos de 2013 são observados em SP e no RJ apenas.

# %% [markdown]
# ## Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo e tire conclusões sobre seus estados comparando com os demais. Tire suas conclusões e compartilhe com a gente.
#
# Foi escolhido o Distrito Federal como comparativo com os estados do sudeste para entender se uma "cidade-estado" com uma provável população menor possui gastos similares com saúde a de um estado inteiro.

# %%
ax = (colunas_interessadas.query('Região == "Sudeste"').loc[:,'2008/Fev':'2020/Jul']/1000000).T.plot(figsize=(10,6), colormap='brg')
ax2 = (colunas_interessadas.loc["53 Distrito Federal"][:-2]/1000000).plot()
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(loc=(1.1,0.5)).set_title('Unidades da Federação')
plt.title('Gastos em procedimentos hospitalares nos estados\n do Sudeste e Distrito Federal - Fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})

plt.show()

# %% [markdown]
# Pelo gráfico percebe-se que os gastos com saúde no Distrito Federal são bem próximos aos do estado do Espírito Santo. Aquele possui uma população estimada para 2020 em 3,15 milhões de habitantes enquanto que este 4.1 milhões. Apesar da diferença de área entre os dois a população não é tão discrepante assim e para se fazer afirmações mais concretas seria importante comparar apenas as duas unidades federativas separadamente dos demais estados do Sudeste.

# %%
ax = (colunas_interessadas.loc["32 Espírito Santo"][:-2]/1000000).T.plot(figsize=(10,6), colormap='brg')
ax2 = (colunas_interessadas.loc["53 Distrito Federal"][:-2]/1000000).plot()
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(loc=(1.1,0.5)).set_title('Unidades da Federação')
plt.title('Gastos em procedimentos hospitalares no Espírito Santo\ne Distrito Federal de fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})

plt.show()

# %%
#Plotando o gráfico com os valores divididos pela população
populacao_ES = 4.1
populacao_DF = 3.15

ax = (colunas_interessadas.loc["32 Espírito Santo"][:-2]/1000000/populacao_ES).T.plot(figsize=(10,6), colormap='brg')
ax2 = (colunas_interessadas.loc["53 Distrito Federal"][:-2]/1000000/populacao_DF).plot()
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.legend(loc=(1.1,0.5)).set_title('Unidades da Federação')
plt.title('Razão dos gastos em procedimentos hospitalares\nem função da população de 2020 no Sudeste e\nDistrito Federal - Agosto de 2007 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em reais por habitante', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})

plt.show()

# %% [markdown]
# Ao dividir pela população percebemos que os gastos nas duas unidades federativas são semelhantes. Foi feita uma simplificação no cálculo uma vez que utilizei a população estimada de 2020 das duas unidades federativas na linha do tempo inteira, ou seja, considerei que a população era igual em 2008 ao que é hoje. Me permiti tal simplificação uma vez que minha intenção era observar se havia uma uma discrepância entre as duas unidades e o "erro populacional" tende a ser parecido nas duas unidades considerando que não existe um evento que justifique um maior crescimento populacional nesse período em alguma delas, ou seja, o "delta" população ao longo dos anos deve ser semelhante.

# %% [markdown]
# # AULA 04 - Análise de gráficos e criação de hipóteses

# %% [markdown]
# ## Desafio 01: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações.

# %%
top_5_index[:3]
# Out:
# ['35 São Paulo', '31 Minas Gerais', '41 Paraná']

# %%
ax = (colunas_interessadas.T[top_5_index[:3]][:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 3 estados com maior\nparticipação - fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# Olhando este gráfico temos a impressão de que o Estado de SP gasta 5-6x mais que o estado do PR, porém isto está sendo induzido pelo fato do eixo y não começar no zero. Farei um exemplo abaixo para deixar mais claro o que estou querendo dizer.

# %%
ax = (colunas_interessadas.T[top_5_index[:3]][:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 3 estados com maior\nparticipação - fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.ylim(100,)
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# Neste gráfico, se não olharmos atentamente para o eixo Y teremos a impressão que o estado do Paraná não gastou com saúde até 2016.

# %% [markdown]
# Não existe uma fórmula mágica. Cada gráfico é um gráfico que precisa contar uma história. No caso em questão o ideal seria o eixo Y começar em R$ 0 milhões.

# %%
ax = (colunas_interessadas.T[top_5_index[:3]][:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares dos 3 estados com maior\nparticipação - fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.ylim(0,)
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# Outra falha que pode ser cometida é utilizar uma parte dos dados que interessa sem um critério bem definido e induzir à interpretações erradas conforme será mostrado nos 3 gráficos abaixo.

# %%
ax = (colunas_interessadas.T[top_5_index[:3]][-12:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
#plt.title('Gastos em procedimentos hospitalares dos 3 estados com maior\nparticipação - fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.ylim(0,)
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# Selecionando apenas os últimos meses temos a impressão de que os gastos com saúde estão caindo.

# %%
ax = (colunas_interessadas.T[top_5_index[:3]][-37:-1] / 1000000).plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.0f}'))
#plt.title('Gastos em procedimentos hospitalares dos 3 estados com maior\nparticipação - fevereiro de 2008 a julho de 2020', {'size':15}).set_color('b')
plt.ylabel('Valores em milhões de reais', {'size':15})
plt.xlabel('Ano/Mês', {'size':15})
plt.ylim(0,)
plt.legend(loc=(1.1,0.4)).set_title('Unidade da Federação')
plt.show()

# %% [markdown]
# Selecionando dados de Agosto de 2017 a julho de 2020 temos a impressão de que os gastos com saúde estão congelados.

# %% [markdown]
# São necessários critérios muito bem definidos para contar a história real do que se quer apresentar. Esse problema ocorre frequentemente nos dados financeiros e os números podem ser manipulados como queremos para defender um ponto de vista.
# Um livro (Como mentir com estatística - Darrell Heff) foi escrito e diversos artigos a respeito do tema e por isso cabe uma grande responsabilidade ao cientista de dados em ser o mais imparcial possível ao fazer uma análise de dados.

# %% [markdown]
# # AULA 05 - Manipulação e interpretação de gráficos

# %%
#@title Análise dos dados mais recentes
mes_mais_recente = ordenado_por_total.columns[-2]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             282709570.31
# 31 Minas Gerais          120467187.34
# 41 Paraná                 80320852.69
# 43 Rio Grande do Sul      78929703.81
# 33 Rio de Janeiro         71540227.33
# 29 Bahia                  58898100.40
# 26 Pernambuco             62325444.34
# 42 Santa Catarina         51764534.76
# 23 Ceará                  30809221.22
# 52 Goiás                  33499284.38
# 15 Pará                   27618727.51
# 21 Maranhão               24374205.15
# 32 Espírito Santo         27460475.47
# 24 Rio Grande do Norte    19593057.45
# 25 Paraíba                15491469.06
# 53 Distrito Federal       22233542.26
# 50 Mato Grosso do Sul     12508717.35
# 22 Piauí                  18019214.49
# 27 Alagoas                13087850.40
# 51 Mato Grosso            13083151.70
# 13 Amazonas               13358514.02
# 28 Sergipe                 3312766.32
# 17 Tocantins               4489665.87
# 11 Rondônia                7407388.24
# ...

# %%
gastos_mais_recente.plot()

# %% [markdown]
# O gráfico pizza geralmente traz uma visualização muito ruim

# %%
gastos_mais_recente.plot(kind='pie')

# %%
gastos_mais_recente.sample(frac=1).plot(kind='pie')

# %% [markdown]
# Para uma visualização simples de valor absoluto uma tabela é mais eficiente

# %%
gastos_mais_recente = gastos_mais_recente/1000000
gastos_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             282.71
# 31 Minas Gerais          120.47
# 41 Paraná                 80.32
# 43 Rio Grande do Sul      78.93
# 33 Rio de Janeiro         71.54
# 29 Bahia                  58.90
# 26 Pernambuco             62.33
# 42 Santa Catarina         51.76
# 23 Ceará                  30.81
# 52 Goiás                  33.50
# 15 Pará                   27.62
# 21 Maranhão               24.37
# 32 Espírito Santo         27.46
# 24 Rio Grande do Norte    19.59
# 25 Paraíba                15.49
# 53 Distrito Federal       22.23
# 50 Mato Grosso do Sul     12.51
# 22 Piauí                  18.02
# 27 Alagoas                13.09
# 51 Mato Grosso            13.08
# 13 Amazonas               13.36
# 28 Sergipe                 3.31
# 17 Tocantins               4.49
# 11 Rondônia                7.41
# 12 Acre                    1.16
# 14 Roraima                 2.74
# 16 Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
#Gastos mais recentes proporcionais ao RJ

gastos_mais_recente / gastos_mais_recente['33 Rio de Janeiro']
# Out:
# Unidade da Federação
# 35 São Paulo             3.95
# 31 Minas Gerais          1.68
# 41 Paraná                1.12
# 43 Rio Grande do Sul     1.10
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.82
# 26 Pernambuco            0.87
# 42 Santa Catarina        0.72
# 23 Ceará                 0.43
# 52 Goiás                 0.47
# 15 Pará                  0.39
# 21 Maranhão              0.34
# 32 Espírito Santo        0.38
# 24 Rio Grande do Norte   0.27
# 25 Paraíba               0.22
# 53 Distrito Federal      0.31
# 50 Mato Grosso do Sul    0.17
# 22 Piauí                 0.25
# 27 Alagoas               0.18
# 51 Mato Grosso           0.18
# 13 Amazonas              0.19
# 28 Sergipe               0.05
# 17 Tocantins             0.06
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.04
# 16 Amapá                 0.03
# Name: 2020/Jul, dtype: float64

# %%
(gastos_mais_recente / gastos_mais_recente.loc['33 Rio de Janeiro']).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.95
# 31 Minas Gerais        1.68
# 41 Paraná              1.12
# 43 Rio Grande do Sul   1.10
# 33 Rio de Janeiro      1.00
# Name: 2020/Jul, dtype: float64

# %%
gastos_mais_recente.plot(kind='bar')

# %% [markdown]
# Alguns valores não estão ordenados pelo gasto mais recente e sim pelo gasto total de 2008 até 2020. Portanto é necessário corrigir para a plotagem contar a história correta dos dados do último mês.

# %%
gastos_mais_recente = gastos_mais_recente.sort_values(ascending=False)
gastos_mais_recente.plot(kind='bar')

# %% [markdown]
# ## Desafio 01: Buscar na documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.
#
# A biblioteca do seaborn já cria um grid, porém acrescentarei o da biblioteca matplotlib.

# %%
gastos_mais_recente = gastos_mais_recente.sort_values(ascending=False)
gastos_mais_recente.plot(kind='bar')
plt.grid(color='black', linestyle='-', linewidth=0.5)

# %% [markdown]
# ## Desafio 02: Fazer um gráfico e uma tabela do gasto dos outros estados em função do seu estado, ou qualquer outro de interesse.

# %%
# Comparativo de gastos mais recentes do estado de São Paulo com os demais estados do Brasil
gastos_mais_recente / gastos_mais_recente['35 São Paulo']
# Out:
# Unidade da Federação
# 35 São Paulo             1.00
# 31 Minas Gerais          0.43
# 41 Paraná                0.28
# 43 Rio Grande do Sul     0.28
# 33 Rio de Janeiro        0.25
# 26 Pernambuco            0.22
# 29 Bahia                 0.21
# 42 Santa Catarina        0.18
# 52 Goiás                 0.12
# 23 Ceará                 0.11
# 15 Pará                  0.10
# 32 Espírito Santo        0.10
# 21 Maranhão              0.09
# 53 Distrito Federal      0.08
# 24 Rio Grande do Norte   0.07
# 22 Piauí                 0.06
# 25 Paraíba               0.05
# 13 Amazonas              0.05
# 27 Alagoas               0.05
# 51 Mato Grosso           0.05
# 50 Mato Grosso do Sul    0.04
# 11 Rondônia              0.03
# 17 Tocantins             0.02
# 28 Sergipe               0.01
# 14 Roraima               0.01
# 16 Amapá                 0.01
# 12 Acre                  0.00
# Name: 2020/Jul, dtype: float64

# %%
(gastos_mais_recente / gastos_mais_recente['35 São Paulo'])[1:].plot(kind='bar', figsize=(10,6))
plt.title('Gastos por estado em função do estado de São Paulo', {'size':20}).set_color('b')
plt.ylabel('Razão entre gastos do estado e o estado de SP')
plt.show()

# %% [markdown]
# ## Desafio 03: Fazer o cálculo proporcional a população do seu estado e mais um a sua escolha.

# %%
# Fonte dos dados do estado de São Paulo: https://pt.wikipedia.org/wiki/S%C3%A3o_Paulo_(estado)
# Fonte dos dados do Paraná: http://www.aen.pr.gov.br/modules/noticias/article.php?storyid=108535&tit=Parana-e-o-5o-Estado-com-a-maior-populacao-do-Pais#:~:text=Segundo%20o%20IBGE%2C%20o%20Estado,Santa%20Catarina%207%2C2%20milh%C3%B5es.
populacao_SP = 45.9
populacao_PR = 11.5

# %%
colunas_interessadas.loc['35 São Paulo'][:-8]
# Out:
# 2008/Fev   172834914.73
# 2008/Mar   170481849.56
# 2008/Abr   170278285.95
# 2008/Mai   172402180.59
# 2008/Jun   175416595.83
#                ...
# 2019/Ago   302367276.77
# 2019/Set   293685713.15
# 2019/Out   303382527.10
# 2019/Nov   282391773.21
# 2019/Dez   272697695.04
# Name: 35 São Paulo, Length: 143, dtype: object

# %%
ax = (colunas_interessadas.loc['35 São Paulo'][:-8] /1000000 / populacao_SP).plot(figsize=(10,6))
ax2 = (colunas_interessadas.loc['41 Paraná'][:-8] /1000000 / populacao_PR).plot()
plt.legend().set_title('Unidades da Federação')
plt.ylabel('Valor em reais gasto por habitante', {'size':15})
plt.xlabel('Ano / Mês', {'size':15})
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Gastos em procedimentos hospitalares em função\nda população do estado de São Paulo e Paraná -\nfevereiro de 2008 a dezembro de 2019', {'size':15}).set_color('b')
plt.show()

# %% [markdown]
# ## Desafio 04: Faça uma análise dos dados analisados, levante hipóteses e compartilhe com a gente no Discord.
#
# Apesar do gasto total do estado de SP ser o maior do Brasil, ao comparar com o do Paraná em função da população percebemos que o estado do PR tem um gasto muito superior, chegando a ser 2x maior que o do estado de SP, por habitante. Uma hipótese é que os estados do Sul tem um histórico muito melhor em questões de saúde em comparação com o restante do País.
